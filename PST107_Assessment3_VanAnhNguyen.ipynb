# %% [markdown]
# <a href="https://colab.research.google.com/github/Anzusu/ADS103-Assessment4/blob/master/PST107_Assessment3_VanAnhNguyen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-36f8b9d4-7f60-433a-a0d0-87b14b07dd3e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-36f8b9d4-7f60-433a-a0d0-87b14b07dd3e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving united-states-rates-of-covid-19-deaths-by-vaccination-status.csv to united-states-rates-of-covid-19-deaths-by-vaccination-status.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats
import matplotlib.pyplot as plt
#%matplotlib inline
import io
df2 = pd.read_csv(io.BytesIO(uploaded['united-states-rates-of-covid-19-deaths-by-vaccination-status.csv']))
data = pd.read_csv("united-states-rates-of-covid-19-deaths-by-vaccination-status.csv")

data.boxplot('Moderna')

# %%
data.boxplot('Pfizer/BioNTech')

# %%
data.boxplot('Fully vaccinated (all vaccines)')

# %%
data.boxplot('Unvaccinated')

# %%
data.boxplot('Johnson&Johnson')

# %%
sns.set_style("whitegrid")
sns.pairplot(data, hue="Entity")
